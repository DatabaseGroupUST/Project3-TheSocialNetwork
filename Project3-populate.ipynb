# %%
# %%capture
# %load_ext sql

# %%
import getpass
username = 'ahmed'   # change this to your username
password = getpass.getpass()
# Out:
# ········

# %%
# %sql mysql+pymysql://$username:$password@db.cs3375.us  # connect to the database
# Out:
# 0 rows affected.
# []

# %%
# %%capture
# %%sql
USE ahmed_university2;
# Out:
# []

# %%
sid = %sql SELECT person_id FROM student limit 6;
sid = list(d[0] for d in sid)
clubs = ["'TriBeta'", "'PANDAS'", "'Pen 15 Club'", "'Kool Kids Klub'", "'American Chemical Society'", "'Pre-health Professionals'"]
mis = ["'We are a science.'", "'We are Python enthusiats.'", "'We are pen collectors.'", "'We are the kool kids of the school'", "'We are american undergraduate chemist'", "'We are future health professions'"]
qlist = [];
query = "INSERT IGNORE INTO STUDENT_CLUBS (club_name,primary_contact,mission_statement) VALUES "
for index in range(len(sid)):
    qlist.append("(" + clubs[index] + "," + str(sid[index]) + "," + mis[index] + ")")
query += ','.join(qlist)
# %sql $query
# Out:
# 6 rows affected.
# 6 rows affected.
# []

# %%
import random
from faker import Faker
fake = Faker()
clubs = %sql SELECT club_name FROM STUDENT_CLUBS;
clubs = list("'"+d[0]+"'" for d in clubs)
for club in clubs:
    start_date = fake.date_time_this_century().isoformat()[0:10]
    query2 = """
    INSERT IGNORE INTO MEMBERSHIP
        SELECT {club} as club_name, person_id as member_id, '{start_date}' as start_id, NULL as end_date
            FROM student
            WHERE RAND()<0.02
    """.format(club=club, start_date=start_date)
    # %sql $query2
# Out:
# 6 rows affected.
# 53 rows affected.
# 67 rows affected.
# 72 rows affected.
# 60 rows affected.
# 67 rows affected.
# 52 rows affected.
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py:166: Warning: (1062, "Duplicate entry 'TriBeta-5474' for key 'PRIMARY'")
#   result = self._query(query)
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py:166: Warning: (1062, "Duplicate entry 'TriBeta-2751' for key 'PRIMARY'")
#   result = self._query(query)
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py:166: Warning: (1062, "Duplicate entry 'TriBeta-9440' for key 'PRIMARY'")
#   result = self._query(query)
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py:166: Warning: (1062, "Duplicate entry 'PANDAS-2863' for key 'PRIMARY'")
#   result = self._query(query)
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py:166: Warning: (1062, "Duplicate entry 'PANDAS-4444' for key 'PRIMARY'")
#   result = self._query(query)
# ...

# %%
import random
from faker import Faker
fake = Faker()
memberships = %sql SELECT club_name, member_id FROM MEMBERSHIP;
for d in memberships:
    query = "INSERT IGNORE INTO MESSAGE_BOARD (author_id, club_name, message) VALUES "
    values = []
    for i in range(10):
        values.append("(" + str(d[1]) + ",'"+d[0]+"','"+fake.text()+"')")
    valstr = ','.join(values)
    query += valstr
    # %sql $query
# Out:
# 789 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# 10 rows affected.
# ...

# %%
import random
from faker import Faker
fake = Faker()
messages = %sql SELECT message_id, author_id, club_name FROM MESSAGE_BOARD WHERE RAND()<0.1;
mlist = []
for m in messages:
    mlist.append([m[0],m[1],m[2]])
for m in mlist:
    query = """
    INSERT IGNORE INTO LIKES (liked_timestamp, liker_id, club_name, author_id, message_id)
        SELECT NOW() as liked_timestamp, member_id as liker_id, '{clubname}' as club_name, {author_id} as author_id, {message_id} as message_id
            FROM MEMBERSHIP
            WHERE club_name = '{clubname}' AND RAND()< 0.1
    """.format(clubname=m[2], author_id=m[1], message_id=m[0])
    # %sql $query
# Out:
# 804 rows affected.
# 19 rows affected.
# 14 rows affected.
# 12 rows affected.
# 16 rows affected.
# 18 rows affected.
# 24 rows affected.
# 15 rows affected.
# 14 rows affected.
# 15 rows affected.
# 14 rows affected.
# 14 rows affected.
# 8 rows affected.
# 15 rows affected.
# 13 rows affected.
# 16 rows affected.
# 13 rows affected.
# 17 rows affected.
# 17 rows affected.
# 15 rows affected.
# 13 rows affected.
# 9 rows affected.
# 15 rows affected.
# 10 rows affected.
# 12 rows affected.
# 12 rows affected.
# 6 rows affected.
# 11 rows affected.
# 9 rows affected.
# 13 rows affected.
# 15 rows affected.
# 15 rows affected.
# 11 rows affected.
# 14 rows affected.
# 14 rows affected.
# 10 rows affected.
# 14 rows affected.
# 13 rows affected.
# 20 rows affected.
# 11 rows affected.
# 18 rows affected.
# 11 rows affected.
# 17 rows affected.
# 9 rows affected.
# 13 rows affected.
# 16 rows affected.
# 13 rows affected.
# 18 rows affected.
# 14 rows affected.
# 8 rows affected.
# ...

# %%
# %%capture
import random

sid1 = %sql SELECT person_id FROM student WHERE RAND()< 0.02;
sid1 = list(d[0] for d in sid1)

sid2 = %sql SELECT person_id FROM student WHERE RAND()< 0.02;
sid2 = list(d[0] for d in sid2)

statuses = ['INVITED', 'ACCEPTED', 'REJECTED']

for s1 in sid1:
    for s2 in sid2:
        query = "INSERT IGNORE INTO FRIENDS (person1a, person2a, person2b, person1b, status) VALUES ({p1}, {p2}, {p2}, {p1}, '{status}')".format(p1=s1, p2=s2, status=random.choice(statuses))
        # %sql $query
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /usr/local/lib/python3.4/dist-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1138                         parameters,
# -> 1139                         context)
#    1140         except Exception as e:
#
# /usr/local/lib/python3.4/dist-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     449     def do_execute(self, cursor, statement, parameters, context=None):
# --> 450         cursor.execute(statement, parameters)
#     451
#
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py in execute(self, query, args)
#     165
# --> 166         result = self._query(query)
#     167         self._executed = query
#
# /usr/local/lib/python3.4/dist-packages/pymysql/cursors.py in _query(self, q)
# ...
